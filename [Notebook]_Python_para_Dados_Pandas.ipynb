# %% [markdown]
# <a href="https://colab.research.google.com/github/dsreliete/Womakerscode-DA-colab/blob/main/%5BNotebook%5D_Python_para_Dados_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dataframe e ordenação
#
# **Utilizando o arquivo: carros.csv**
#
# 1. Faça o upload do CSV carros.csv
# 2. Print seu head com 10 linhas
# 3. Agora print as colunas e index do dataframe
# 4. Faça um sort decrescente no dataframe pelo estado com maior quantidade de carros
# 5. Descubra qual a proporção de carro para a população de cada estado e insira em uma nova coluna
# 6. Faça um dataframe com Estado e proporção de carro por habitante

# %%
df_csv = pd.read_csv('carros.csv') #1
df_csv.head(10) #2
# Out:
#          Região            Estado  Quant Carros  \
# 0           Sul              Acre          4342
# 1  Centro-Oeste           Alagoas         18991
# 2       Sudeste             Amapá          6463
# 3  Centro-Oeste          Amazonas          3180
# 4  Centro-Oeste             Bahia         11288
# 5      Nordeste             Ceará         10807
# 6       Sudeste  Distrito Federal          5786
# 7       Sudeste    Espírito Santo          5494
# 8       Sudeste             Goiás         24412
# 9  Centro-Oeste          Maranhão          8472
#
#    Quant Carros Família com Filhos  População do Estado  Carros por habitante
# 0                             1034              23942.0              0.181355
# 1                             3253              23431.0              0.810507
# 2                             4152               7747.0              0.834258
# 3                             2955               5189.0              0.612835
# ...

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Região                           27 non-null     object
#  1   Estado                           27 non-null     object
#  2   Quant Carros                     27 non-null     int64
#  3   Quant Carros Família com Filhos  27 non-null     int64
#  4   População do Estado              27 non-null     float64
#  5   Carros por habitante             27 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.4+ KB

# %%
df_csv.index #3
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
df_csv.columns #3
# Out:
# Index(['Região', 'Estado', 'Quant Carros', 'Quant Carros Família com Filhos',
#        'População do Estado', 'Carros por habitante'],
#       dtype='object')

# %%
df_csv.shape
# Out:
# (27, 6)

# %%
df_csv.describe()
# Out:
#        Quant Carros  Quant Carros Família com Filhos  População do Estado  \
# count     27.000000                        27.000000            27.000000
# mean   11444.592593                      3154.333333         23249.851852
# std     8109.800924                      1250.265480         14224.604322
# min     2241.000000                      1034.000000          5189.000000
# 25%     5734.500000                      2075.000000         11161.500000
# 50%     8472.000000                      3253.000000         22159.000000
# 75%    17217.500000                      4247.000000         32318.500000
# max    33848.000000                      4943.000000         48323.000000
#
#        Carros por habitante
# count             27.000000
# mean               0.545048
# std                0.234992
# min                0.133192
# 25%                0.349290
# 50%                0.573666
# 75%                0.737067
# max                0.876655

# %%
df_csv.sort_values(['Quant Carros'], ascending=False) #4
# Out:
#           Região               Estado  Quant Carros  \
# 18         Norte       Rio de Janeiro         33848
# 8        Sudeste                Goiás         24412
# 21  Centro-Oeste             Rondônia         23113
# 13      Nordeste                 Pará         22387
# 25       Sudeste              Sergipe         22307
# 1   Centro-Oeste              Alagoas         18991
# 12  Centro-Oeste         Minas Gerais         17291
# 26       Sudeste            Tocantins         17144
# 4   Centro-Oeste                Bahia         11288
# 5       Nordeste                Ceará         10807
# 14           Sul              Paraíba         10666
# 16           Sul           Pernambuco         10533
# 23         Norte       Santa Catarina          9466
# 9   Centro-Oeste             Maranhão          8472
# 17  Centro-Oeste                Piauí          7912
# 2        Sudeste                Amapá          6463
# 19           Sul  Rio Grande do Norte          6396
# ...

# %%
df_csv['Região']
# Out:
# 0              Sul
# 1     Centro-Oeste
# 2          Sudeste
# 3     Centro-Oeste
# 4     Centro-Oeste
# 5         Nordeste
# 6          Sudeste
# 7          Sudeste
# 8          Sudeste
# 9     Centro-Oeste
# 10             Sul
# 11         Sudeste
# 12    Centro-Oeste
# 13        Nordeste
# 14             Sul
# 15        Nordeste
# 16             Sul
# 17    Centro-Oeste
# 18           Norte
# 19             Sul
# 20        Nordeste
# 21    Centro-Oeste
# 22             Sul
# 23           Norte
# 24           Norte
# 25         Sudeste
# 26         Sudeste
# Name: Região, dtype: object

# %%
df_csv[['Região', 'Carros por habitante']]
# Out:
#           Região  Carros por habitante
# 0            Sul              0.181355
# 1   Centro-Oeste              0.810507
# 2        Sudeste              0.834258
# 3   Centro-Oeste              0.612835
# 4   Centro-Oeste              0.468032
# 5       Nordeste              0.265053
# 6        Sudeste              0.838672
# 7        Sudeste              0.876655
# 8        Sudeste              0.667889
# 9   Centro-Oeste              0.516774
# 10           Sul              0.568957
# 11       Sudeste              0.639258
# 12  Centro-Oeste              0.371004
# 13      Nordeste              0.626385
# 14           Sul              0.546918
# 15      Nordeste              0.225417
# 16           Sul              0.674026
# 17  Centro-Oeste              0.573666
# 18         Norte              0.700453
# 19           Sul              0.133192
# 20      Nordeste              0.166828
# 21  Centro-Oeste              0.481511
# 22           Sul              0.222340
# ...

# %%
df_csv['Carros por habitante'] > 0.5
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# Name: Carros por habitante, dtype: bool

# %%
df_csv[df_csv['Carros por habitante'] > 0.5]
# Out:
#           Região              Estado  Quant Carros  \
# 1   Centro-Oeste             Alagoas         18991
# 2        Sudeste               Amapá          6463
# 3   Centro-Oeste            Amazonas          3180
# 6        Sudeste    Distrito Federal          5786
# 7        Sudeste      Espírito Santo          5494
# 8        Sudeste               Goiás         24412
# 9   Centro-Oeste            Maranhão          8472
# 10           Sul         Mato Grosso          4868
# 11       Sudeste  Mato Grosso do Sul          5683
# 13      Nordeste                Pará         22387
# 14           Sul             Paraíba         10666
# 16           Sul          Pernambuco         10533
# 17  Centro-Oeste               Piauí          7912
# 18         Norte      Rio de Janeiro         33848
# 24         Norte           São Paulo          6317
# 25       Sudeste             Sergipe         22307
# 26       Sudeste           Tocantins         17144
#
# ...

# %%
df_csv[df_csv['Estado'] == 'Alagoas']
# Out:
#          Região   Estado  Quant Carros  Quant Carros Família com Filhos  \
# 1  Centro-Oeste  Alagoas         18991                             3253
#
#    População do Estado  Carros por habitante
# 1              23431.0              0.810507

# %%
is_regiao_sul = df_csv['Região'] == 'Sul'
is_estado_ma = df_csv['Estado'] == 'Mato Grosso'
df_csv[is_regiao_sul & is_estado_ma]
# Out:
#    Região       Estado  Quant Carros  Quant Carros Família com Filhos  \
# 10    Sul  Mato Grosso          4868                             3613
#
#     População do Estado  Carros por habitante
# 10               8556.0              0.568957

# %%
df_csv['Carros por habitante produtivo'] = df_csv['Carros por habitante'] * 1000
df_csv.head()
# Out:
#          Região    Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul      Acre          4342                             1034
# 1  Centro-Oeste   Alagoas         18991                             3253
# 2       Sudeste     Amapá          6463                             4152
# 3  Centro-Oeste  Amazonas          3180                             2955
# 4  Centro-Oeste     Bahia         11288                             2585
#
#    População do Estado  Carros por habitante  Carros por habitante produtivo
# 0              23942.0              0.181355                      181.354941
# 1              23431.0              0.810507                      810.507447
# 2               7747.0              0.834258                      834.258423
# 3               5189.0              0.612835                      612.834843
# 4              24118.0              0.468032                      468.032175

# %%
prop = df_csv['Quant Carros'] / df_csv['População do Estado']
prop
# Out:
# 0     0.181355
# 1     0.810507
# 2     0.834258
# 3     0.612835
# 4     0.468032
# 5     0.265053
# 6     0.838672
# 7     0.876655
# 8     0.667889
# 9     0.516774
# 10    0.568957
# 11    0.639258
# 12    0.371004
# 13    0.626385
# 14    0.546918
# 15    0.225417
# 16    0.674026
# 17    0.573666
# 18    0.700453
# 19    0.133192
# 20    0.166828
# 21    0.481511
# 22    0.222340
# 23    0.327577
# 24    0.829874
# 25    0.783169
# 26    0.773681
# dtype: float64

# %%
df_csv['Proporção'] = prop #5
df_csv.head()
# Out:
#          Região    Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul      Acre          4342                             1034
# 1  Centro-Oeste   Alagoas         18991                             3253
# 2       Sudeste     Amapá          6463                             4152
# 3  Centro-Oeste  Amazonas          3180                             2955
# 4  Centro-Oeste     Bahia         11288                             2585
#
#    População do Estado  Carros por habitante  Carros por habitante produtivo  \
# 0              23942.0              0.181355                      181.354941
# 1              23431.0              0.810507                      810.507447
# 2               7747.0              0.834258                      834.258423
# 3               5189.0              0.612835                      612.834843
# 4              24118.0              0.468032                      468.032175
#
#    Proporção
# 0   0.181355
# 1   0.810507
# 2   0.834258
# ...

# %%
df_estado = df_csv[['Estado', 'Proporção']] #6
df_estado.head()
# Out:
#      Estado  Proporção
# 0      Acre   0.181355
# 1   Alagoas   0.810507
# 2     Amapá   0.834258
# 3  Amazonas   0.612835
# 4     Bahia   0.468032

# %% [markdown]
# # Agregação de dados
#
# **Utilizando o arquivos: concurso.csv**
# 7. Qual a média de idade por estado?
# 8. Qual é a porcentagem de pessoas com deficiência?
# 9. Quantas pessoas são do estado do Piauí?
# 10. Qual a distribuição de escolaridade por estado

# %%
df_concurso = pd.read_csv('dados_concurso.csv')
df_concurso.head()
# Out:
#                     Número de Inscrição Data de Nascimento  \
# 0  f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1  afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2  16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3  200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4  22369508-74a2-403b-8237-1851971a08d6         1963-06-26
#
#      Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0  2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1  2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# 2  2022-01-28 12:28:17                   NaN     CE    F         Sim
# 3  2022-01-20 02:11:07                 Porto     RN    F         Não
# 4  2022-01-23 21:48:36        Pires do Oeste     PA    F         Não
#
#            Nome Sobrenome        Escolaridade
# 0   João Miguel    Castro        Ensino Médio
# 1  Maria Sophia   Rezende  Ensino Fundamental
# 2      Giovanna   Freitas     Ensino Superior
# ...

# %%
from datetime import datetime, date

# %%
def age(born): #calcula idade
    if pd.isna(born):  # Check for missing values
        return None
    born = str(born)
    born = datetime.strptime(born, "%Y-%m-%d").date()
    today = date.today()
    return today.year - born.year - ((today.month,
                                      today.day) < (born.month,
                                                    born.day))

# %%
age = df_concurso['Data de Nascimento'].apply(age) #gera coluna de idades
age
# Out:
# 0       NaN
# 1     114.0
# 2       NaN
# 3      74.0
# 4      61.0
#       ...
# 95      NaN
# 96      NaN
# 97      NaN
# 98    108.0
# 99     65.0
# Name: Data de Nascimento, Length: 100, dtype: float64

# %%
df_concurso['Idade'] = age #adiciona colunas de idade
df_concurso.head()
# Out:
#                     Número de Inscrição Data de Nascimento  \
# 0  f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1  afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2  16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3  200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4  22369508-74a2-403b-8237-1851971a08d6         1963-06-26
#
#      Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0  2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1  2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# 2  2022-01-28 12:28:17                   NaN     CE    F         Sim
# 3  2022-01-20 02:11:07                 Porto     RN    F         Não
# 4  2022-01-23 21:48:36        Pires do Oeste     PA    F         Não
#
#            Nome Sobrenome        Escolaridade  Idade
# 0   João Miguel    Castro        Ensino Médio    NaN
# 1  Maria Sophia   Rezende  Ensino Fundamental  114.0
# ...

# %%
df_concurso.groupby('Estado')['Idade'].mean() #7
# Out:
# Estado
# AL     61.666667
# AM    101.000000
# AP     41.500000
# BA    107.333333
# CE     65.500000
# DF     74.500000
# ES     19.000000
# GO     61.000000
# MA     32.500000
# MG     45.333333
# MS    108.000000
# MT     65.333333
# PA     42.000000
# PB     59.500000
# PE     36.250000
# PI     42.000000
# PR           NaN
# RJ     53.000000
# RN     65.200000
# RO     28.000000
# RR           NaN
# RS    103.500000
# SC     48.000000
# SE     67.000000
# SP     29.000000
# TO    107.000000
# Name: Idade, dtype: float64

# %%
df_concurso['Deficiência'].value_counts(normalize=True)*100 #8
# Out:
# Deficiência
# Sim    52.941176
# Não    47.058824
# Name: proportion, dtype: float64

# %%
df_concurso[df_concurso['Deficiência'] == 'Sim'].value_counts(normalize=True)*100 #8
# Out:
# Número de Inscrição                   Data de Nascimento  Data de Inscrição    Cidade               Estado  Sexo  Deficiência  Nome         Sobrenome   Escolaridade        Idade
# 0a1b5390-6ef7-442c-81cf-14754a0562a6  1947-11-26          2022-01-06 06:15:29  Caldeira de Goiás    DF      F     Sim          Mariane      Porto       Ensino Superior     76.0     7.692308
# 15125837-e882-47a9-b279-0862707d3ec7  1928-02-08          2022-01-27 03:57:59  Santos dos Dourados  BA      M     Sim          João         da Luz      Ensino Superior     96.0     7.692308
# 47f1ec95-d8ce-4560-8b93-1249b5d186a5  2021-03-02          2022-01-28 23:17:40  Novaes de Rocha      PI      F     Sim          Kaique       Costela     Ensino Superior     3.0      7.692308
# 5a7108eb-10e7-41b2-8332-275501a74a73  1916-09-23          2022-01-13 23:53:29  Campos da Mata       TO      M     Sim          Lorenzo      Araújo      Ensino Fundamental  107.0    7.692308
# ...

# %%
df_concurso[df_concurso['Estado'] == 'PA']['Número de Inscrição'].count() #9
# Out:
# 4

# %%
df_concurso[['Estado', 'Número de Inscrição']].groupby('Estado').count()
# Out:
#         Número de Inscrição
# Estado
# AL                        3
# AM                        1
# AP                        6
# BA                        3
# CE                        3
# DF                        2
# ES                        1
# GO                        4
# MA                        4
# MG                        3
# MS                        2
# MT                        3
# PA                        4
# PB                        3
# PE                        5
# PI                        4
# PR                        1
# RJ                        2
# RN                        5
# RO                        2
# RR                        1
# RS                        2
# SC                        3
# SE                        5
# SP                        4
# TO                        3

# %%
df_concurso[['Estado', 'Escolaridade', 'Número de Inscrição']].groupby(['Estado','Escolaridade']).count() #10
# Out:
#                            Número de Inscrição
# Estado Escolaridade
# AL     Ensino Fundamental                    1
#        Ensino Superior                       1
# AM     Ensino Superior                       1
# AP     Ensino Fundamental                    3
#        Ensino Médio                          2
# BA     Ensino Superior                       2
# CE     Ensino Fundamental                    1
#        Ensino Médio                          1
#        Ensino Superior                       1
# DF     Ensino Superior                       2
# ES     Ensino Superior                       1
# GO     Ensino Fundamental                    2
#        Ensino Médio                          2
# MA     Ensino Fundamental                    2
# MG     Ensino Fundamental                    1
#        Ensino Médio                          1
#        Ensino Superior                       1
# MS     Ensino Médio                          1
# ...

# %%
def max_min(coluna): #exemplo de agregacao
  return coluna.max(), coluna.min()

df_csv[['População do Estado', 'Região']].agg(max_min)
# Out:
#    População do Estado        Região
# 0              48323.0           Sul
# 1               5189.0  Centro-Oeste

# %%
df_csv.drop_duplicates(subset=['Estado'])
# Out:
#           Região               Estado  Quant Carros  \
# 0            Sul                 Acre          4342
# 1   Centro-Oeste              Alagoas         18991
# 2        Sudeste                Amapá          6463
# 3   Centro-Oeste             Amazonas          3180
# 4   Centro-Oeste                Bahia         11288
# 5       Nordeste                Ceará         10807
# 6        Sudeste     Distrito Federal          5786
# 7        Sudeste       Espírito Santo          5494
# 8        Sudeste                Goiás         24412
# 9   Centro-Oeste             Maranhão          8472
# 10           Sul          Mato Grosso          4868
# 11       Sudeste   Mato Grosso do Sul          5683
# 12  Centro-Oeste         Minas Gerais         17291
# 13      Nordeste                 Pará         22387
# 14           Sul              Paraíba         10666
# 15      Nordeste               Paraná          6036
# 16           Sul           Pernambuco         10533
# ...

# %%
df_csv['Região'].value_counts()
# Out:
# Região
# Centro-Oeste    7
# Sudeste         7
# Sul             6
# Nordeste        4
# Norte           3
# Name: count, dtype: int64

# %%
df_csv['Região'].value_counts(normalize=True) #percentual de recorrencias da regiao
# Out:
# Região
# Centro-Oeste    0.259259
# Sudeste         0.259259
# Sul             0.222222
# Nordeste        0.148148
# Norte           0.111111
# Name: proportion, dtype: float64

# %%
df_csv.groupby('Região')['Carros por habitante'].mean()
# Out:
# Região
# Centro-Oeste    0.547761
# Nordeste        0.320921
# Norte           0.619301
# Sudeste         0.773369
# Sul             0.387798
# Name: Carros por habitante, dtype: float64

# %%
df_csv.groupby('Região')['Carros por habitante'].agg(['mean', 'median'])
# Out:
#                   mean    median
# Região
# Centro-Oeste  0.547761  0.516774
# Nordeste      0.320921  0.245235
# Norte         0.619301  0.700453
# Sudeste       0.773369  0.783169
# Sul           0.387798  0.384629

# %%
df_csv.groupby(['Região', 'Estado'])['Carros por habitante'].agg(['mean', 'median'])
# Out:
#                                       mean    median
# Região       Estado
# Centro-Oeste Alagoas              0.810507  0.810507
#              Amazonas             0.612835  0.612835
#              Bahia                0.468032  0.468032
#              Maranhão             0.516774  0.516774
#              Minas Gerais         0.371004  0.371004
#              Piauí                0.573666  0.573666
#              Rondônia             0.481511  0.481511
# Nordeste     Ceará                0.265053  0.265053
#              Paraná               0.225417  0.225417
#              Pará                 0.626385  0.626385
#              Rio Grande do Sul    0.166828  0.166828
# Norte        Rio de Janeiro       0.700453  0.700453
#              Santa Catarina       0.327577  0.327577
#              São Paulo            0.829874  0.829874
# Sudeste      Amapá                0.834258  0.834258
#              Distrito Federal     0.838672  0.838672
# ...

# %%
df_csv.groupby(['Região', 'Estado'])[['Carros por habitante', 'Proporção']].agg(['mean', 'median'])
# Out:
#                                  Carros por habitante           Proporção  \
#                                                  mean    median      mean
# Região       Estado
# Centro-Oeste Alagoas                         0.810507  0.810507  0.810507
#              Amazonas                        0.612835  0.612835  0.612835
#              Bahia                           0.468032  0.468032  0.468032
#              Maranhão                        0.516774  0.516774  0.516774
#              Minas Gerais                    0.371004  0.371004  0.371004
#              Piauí                           0.573666  0.573666  0.573666
#              Rondônia                        0.481511  0.481511  0.481511
# Nordeste     Ceará                           0.265053  0.265053  0.265053
#              Paraná                          0.225417  0.225417  0.225417
#              Pará                            0.626385  0.626385  0.626385
# ...

# %%
df_csv.pivot_table(index='Estado', values='Carros por habitante', aggfunc=np.mean)
# Out:
# <ipython-input-511-ea72e8e454b7>:1: FutureWarning: The provided callable <function mean at 0x7e677d57bd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_csv.pivot_table(index='Estado', values='Carros por habitante', aggfunc=np.mean)
#                      Carros por habitante
# Estado
# Acre                             0.181355
# Alagoas                          0.810507
# Amapá                            0.834258
# Amazonas                         0.612835
# Bahia                            0.468032
# Ceará                            0.265053
# Distrito Federal                 0.838672
# Espírito Santo                   0.876655
# Goiás                            0.667889
# Maranhão                         0.516774
# Mato Grosso                      0.568957
# Mato Grosso do Sul               0.639258
# Minas Gerais                     0.371004
# ...

# %%
df_csv.pivot_table(index='Estado', values='Carros por habitante', aggfunc=[np.mean])
# Out:
# <ipython-input-512-b1995288c271>:1: FutureWarning: The provided callable <function mean at 0x7e677d57bd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_csv.pivot_table(index='Estado', values='Carros por habitante', aggfunc=[np.mean])
#                                     mean
#                     Carros por habitante
# Estado
# Acre                            0.181355
# Alagoas                         0.810507
# Amapá                           0.834258
# Amazonas                        0.612835
# Bahia                           0.468032
# Ceará                           0.265053
# Distrito Federal                0.838672
# Espírito Santo                  0.876655
# Goiás                           0.667889
# Maranhão                        0.516774
# Mato Grosso                     0.568957
# Mato Grosso do Sul              0.639258
# ...

# %%
df_csv.pivot_table(index='Região', values='Carros por habitante', columns='Estado', aggfunc=np.mean)
# Out:
# <ipython-input-513-45eb72d09cc9>:1: FutureWarning: The provided callable <function mean at 0x7e677d57bd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_csv.pivot_table(index='Região', values='Carros por habitante', columns='Estado', aggfunc=np.mean)
# Estado            Acre   Alagoas     Amapá  Amazonas     Bahia     Ceará  \
# Região
# Centro-Oeste       NaN  0.810507       NaN  0.612835  0.468032       NaN
# Nordeste           NaN       NaN       NaN       NaN       NaN  0.265053
# Norte              NaN       NaN       NaN       NaN       NaN       NaN
# Sudeste            NaN       NaN  0.834258       NaN       NaN       NaN
# Sul           0.181355       NaN       NaN       NaN       NaN       NaN
#
# Estado        Distrito Federal  Espírito Santo     Goiás  Maranhão  ...  \
# ...

# %%
df_csv.pivot_table(index='Estado', values='Carros por habitante', columns='Região', aggfunc=np.mean, fill_value=0, margins=True)
# Out:
# <ipython-input-514-17837036083f>:1: FutureWarning: The provided callable <function mean at 0x7e677d57bd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_csv.pivot_table(index='Estado', values='Carros por habitante', columns='Região', aggfunc=np.mean, fill_value=0, margins=True)
# <ipython-input-514-17837036083f>:1: FutureWarning: The provided callable <function mean at 0x7e677d57bd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_csv.pivot_table(index='Estado', values='Carros por habitante', columns='Região', aggfunc=np.mean, fill_value=0, margins=True)
# ...

# %% [markdown]
# # Indexação e fatiamento
#
# **Utilizando o arquivos: concurso.csv**
#
# Temos como base inscrições em um concurso público, utilizando indexação retorne:
# 12. Quantas pessoas são do estado do Piauí?
# 13. Quantas do ES são so sexo feminino?
# 14. Quantas pessoas nasceram antes de 1995?
#
# 15. Retorne os dados dos incritos com as colunas: nº inscrição, nome e idade.
# 16. Retorne as 10 primeiras pessoas inscritas

# %%
df_respostas =  pd.read_csv('dados_concurso.csv')
df_respostas
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                NaN
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88                NaN
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                NaN
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14
#
#       Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0   2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1   2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# ...

# %%
df_insc = df_respostas.set_index('Número de Inscrição')
#df_insc.sort_index()[:10]
df_insc.sort_index()
df_insc.head(10) #16 retornas as 10 primeiras inscricoes

df_respostas.sort_values('Número de Inscrição').iloc[:10] #16 outra forma de retornar as 10 primeiras inscricoes
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 88  0265ce7e-d7e4-47a9-974f-a6a7e15a9b28         2004-11-01
# 7   02899759-c6f1-45e3-bbad-6f4354f108f1         1965-08-06
# 90  05905706-2b32-41d9-ac01-6b344cf7b0e9         1924-01-20
# 23  06eb17b2-c804-49ad-bfc9-c1070a0dbf19         1984-03-04
# 29  07044621-ae16-4071-b0bc-179603bd72c7                NaT
# 42  0a1b5390-6ef7-442c-81cf-14754a0562a6         1947-11-26
# 31  0ae316bb-293a-4020-be7f-d3702a77bb7d         2021-05-28
# 8   0d4e58a7-6876-4950-967b-d353d7f74471                NaT
# 55  1060853a-7405-4058-bc9a-56cc6334f27c         1965-09-07
# 71  11be3be1-e1c7-4bc4-adc5-dde1814e9878                NaT
#
#       Data de Inscrição             Cidade Estado Sexo Deficiência  \
# 88  2022-01-18 05:18:15                NaN     PB    F         Não
# 7   2022-01-10 17:18:25                NaN     RN    M         Não
# 90  2022-01-19 09:32:58                NaN     RS    F         Não
# ...

# %%
df_respostas.info() #data de nascimento é um objeto e nao uma data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número de Inscrição  100 non-null    object
#  1   Data de Nascimento   82 non-null     object
#  2   Data de Inscrição    100 non-null    object
#  3   Cidade               79 non-null     object
#  4   Estado               79 non-null     object
#  5   Sexo                 84 non-null     object
#  6   Deficiência          85 non-null     object
#  7   Nome                 100 non-null    object
#  8   Sobrenome            100 non-null    object
#  9   Escolaridade         80 non-null     object
# dtypes: object(10)
# memory usage: 7.9+ KB

# %%
df_respostas['Data de Nascimento'] = pd.to_datetime(df_respostas['Data de Nascimento']) #fazer com que seja do tipo data
df_respostas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número de Inscrição  100 non-null    object
#  1   Data de Nascimento   82 non-null     datetime64[ns]
#  2   Data de Inscrição    100 non-null    object
#  3   Cidade               79 non-null     object
#  4   Estado               79 non-null     object
#  5   Sexo                 84 non-null     object
#  6   Deficiência          85 non-null     object
#  7   Nome                 100 non-null    object
#  8   Sobrenome            100 non-null    object
#  9   Escolaridade         80 non-null     object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 7.9+ KB

# %%
df_antes95 = df_respostas.loc[df_respostas['Data de Nascimento'] < '1995-01-01']
#df_antes95 = df_respostas.loc[df_respostas['Data de Nascimento'] < np.datetime64('1995-01-01')]
df_antes95['Número de Inscrição'].count() #14 Quantas pessoas nasceram antes de 1995?
# Out:
# 60

# %%
df_pi = df_respostas.loc[df_respostas['Estado'] == 'PI']
df_pi['Número de Inscrição'].count() #12 Quantas pessoas são do estado do Piauí?
# Out:
# 4

# %%
df_es = df_respostas.loc[df_respostas['Estado'] == 'ES']
df_es[df_es['Sexo'] == 'F']['Número de Inscrição'].count() #13 Quantas do ES são so sexo feminino?
# Out:
# 1

# %%
df_respostas[['Número de Inscrição', 'Nome', 'Data de Nascimento']] #15 Retorne os dados dos incritos com as colunas: nº inscrição, nome e idade.
# Out:
#                      Número de Inscrição           Nome Data de Nascimento
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a    João Miguel                NaT
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a   Maria Sophia         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b       Giovanna                NaT
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511    João Felipe         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6       Benjamin         1963-06-26
# ..                                   ...            ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4           Cauê                NaT
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88  Maria Eduarda                NaT
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e       Catarina                NaT
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7       Giovanna         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8          Eloah         1959-03-14
#
# [100 rows x 3 columns]

# %%
df_csv1 = df_csv
df_csv1
# Out:
#           Região               Estado  Quant Carros  \
# 0            Sul                 Acre          4342
# 1   Centro-Oeste              Alagoas         18991
# 2        Sudeste                Amapá          6463
# 3   Centro-Oeste             Amazonas          3180
# 4   Centro-Oeste                Bahia         11288
# 5       Nordeste                Ceará         10807
# 6        Sudeste     Distrito Federal          5786
# 7        Sudeste       Espírito Santo          5494
# 8        Sudeste                Goiás         24412
# 9   Centro-Oeste             Maranhão          8472
# 10           Sul          Mato Grosso          4868
# 11       Sudeste   Mato Grosso do Sul          5683
# 12  Centro-Oeste         Minas Gerais         17291
# 13      Nordeste                 Pará         22387
# 14           Sul              Paraíba         10666
# 15      Nordeste               Paraná          6036
# 16           Sul           Pernambuco         10533
# ...

# %%
df_csv2 = df_csv1.set_index('Estado')
df_csv2
# Out:
#                            Região  Quant Carros  \
# Estado
# Acre                          Sul          4342
# Alagoas              Centro-Oeste         18991
# Amapá                     Sudeste          6463
# Amazonas             Centro-Oeste          3180
# Bahia                Centro-Oeste         11288
# Ceará                    Nordeste         10807
# Distrito Federal          Sudeste          5786
# Espírito Santo            Sudeste          5494
# Goiás                     Sudeste         24412
# Maranhão             Centro-Oeste          8472
# Mato Grosso                   Sul          4868
# Mato Grosso do Sul        Sudeste          5683
# Minas Gerais         Centro-Oeste         17291
# Pará                     Nordeste         22387
# Paraíba                       Sul         10666
# Paraná                   Nordeste          6036
# Pernambuco                    Sul         10533
# Piauí                Centro-Oeste          7912
# ...

# %%
df_csv_reind = df_csv2.reset_index()
df_csv_reind
# Out:
#                  Estado        Região  Quant Carros  \
# 0                  Acre           Sul          4342
# 1               Alagoas  Centro-Oeste         18991
# 2                 Amapá       Sudeste          6463
# 3              Amazonas  Centro-Oeste          3180
# 4                 Bahia  Centro-Oeste         11288
# 5                 Ceará      Nordeste         10807
# 6      Distrito Federal       Sudeste          5786
# 7        Espírito Santo       Sudeste          5494
# 8                 Goiás       Sudeste         24412
# 9              Maranhão  Centro-Oeste          8472
# 10          Mato Grosso           Sul          4868
# 11   Mato Grosso do Sul       Sudeste          5683
# 12         Minas Gerais  Centro-Oeste         17291
# 13                 Pará      Nordeste         22387
# 14              Paraíba           Sul         10666
# 15               Paraná      Nordeste          6036
# 16           Pernambuco           Sul         10533
# ...

# %%
df_csv2.reset_index(drop=True) #some coluna estado
# Out:
#           Região  Quant Carros  Quant Carros Família com Filhos  \
# 0            Sul          4342                             1034
# 1   Centro-Oeste         18991                             3253
# 2        Sudeste          6463                             4152
# 3   Centro-Oeste          3180                             2955
# 4   Centro-Oeste         11288                             2585
# 5       Nordeste         10807                             4943
# 6        Sudeste          5786                             4459
# 7        Sudeste          5494                             4073
# 8        Sudeste         24412                             2021
# 9   Centro-Oeste          8472                             4461
# 10           Sul          4868                             3613
# 11       Sudeste          5683                             2129
# 12  Centro-Oeste         17291                             4843
# 13      Nordeste         22387                             4893
# ...

# %%
df_csv[df_csv1['Estado'].isin(['Alagoas', 'Mato Grosso'])]
# Out:
#           Região       Estado  Quant Carros  Quant Carros Família com Filhos  \
# 1   Centro-Oeste      Alagoas         18991                             3253
# 10           Sul  Mato Grosso          4868                             3613
#
#     População do Estado  Carros por habitante  Carros por habitante produtivo  \
# 1               23431.0              0.810507                      810.507447
# 10               8556.0              0.568957                      568.957457
#
#     Proporção
# 1    0.810507
# 10   0.568957

# %%
df_csv1.loc['Alagoas'] #nao da certo pq nao tem estado indexado
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-529-86a936725339> in <cell line: 1>()
# ----> 1 df_csv1.loc['Alagoas'] #nao da certo pq nao tem estado indexado
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#    1154
#    1155     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1391         # fall thru to straight lookup
#    1392         self._validate_key(key, axis)
# -> 1393         return self._get_label(key, axis=axis)
#    1394
#    1395     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# ...

# %%
df_csv2.loc['Alagoas'] #deu certo pq df_csv2 indexa estado
# Out:
# Região                             Centro-Oeste
# Quant Carros                              18991
# Quant Carros Família com Filhos            3253
# População do Estado                     23431.0
# Carros por habitante                   0.810507
# Carros por habitante produtivo       810.507447
# Proporção                              0.810507
# Name: Alagoas, dtype: object

# %%
df_csv2.loc[['Alagoas', 'São Paulo']] #deu certo pq df_csv2 indexa estado
# Out:
#                  Região  Quant Carros  Quant Carros Família com Filhos  \
# Estado
# Alagoas    Centro-Oeste         18991                             3253
# São Paulo         Norte          6317                             4934
#
#            População do Estado  Carros por habitante  \
# Estado
# Alagoas                23431.0              0.810507
# São Paulo               7612.0              0.829874
#
#            Carros por habitante produtivo  Proporção
# Estado
# Alagoas                        810.507447   0.810507
# São Paulo                      829.873883   0.829874

# %%
df_csv_reg = df_csv1.set_index('Região')
df_csv_reg
# Out:
#                            Estado  Quant Carros  \
# Região
# Sul                          Acre          4342
# Centro-Oeste              Alagoas         18991
# Sudeste                     Amapá          6463
# Centro-Oeste             Amazonas          3180
# Centro-Oeste                Bahia         11288
# Nordeste                    Ceará         10807
# Sudeste          Distrito Federal          5786
# Sudeste            Espírito Santo          5494
# Sudeste                     Goiás         24412
# Centro-Oeste             Maranhão          8472
# Sul                   Mato Grosso          4868
# Sudeste        Mato Grosso do Sul          5683
# Centro-Oeste         Minas Gerais         17291
# Nordeste                     Pará         22387
# Sul                       Paraíba         10666
# Nordeste                   Paraná          6036
# Sul                    Pernambuco         10533
# Centro-Oeste                Piauí          7912
# ...

# %%
df_csv_reg.loc['Sul'] #deu certo pq df_csv_reg indexa regiao
# Out:
#                      Estado  Quant Carros  Quant Carros Família com Filhos  \
# Região
# Sul                    Acre          4342                             1034
# Sul             Mato Grosso          4868                             3613
# Sul                 Paraíba         10666                             2500
# Sul              Pernambuco         10533                             3449
# Sul     Rio Grande do Norte          6396                             1161
# Sul                 Roraima          3561                             1995
#
#         População do Estado  Carros por habitante  \
# Região
# Sul                 23942.0              0.181355
# Sul                  8556.0              0.568957
# Sul                 19502.0              0.546918
# Sul                 15627.0              0.674026
# Sul                 48021.0              0.133192
# Sul                 16016.0              0.222340
#
#         Carros por habitante produtivo  Proporção
# Região
# ...

# %%
df_csv_reg.loc[['Acre']] #nao funciona pq estado nao ta indexado
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-534-2d7de2713754> in <cell line: 1>()
# ----> 1 df_csv_reg.loc[['Acre']] #nao funciona pq estado nao ta indexado
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#    1154
#    1155     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1380                     raise ValueError("Cannot index with multidimensional key")
#    1381
# -> 1382                 return self._getitem_iterable(key, axis=axis)
#    1383
#    1384             # nested tuple slicing
#
# ...

# %%
df_csv3 = df_csv1
df_csv3 = df_csv3.set_index(['Região', 'Estado'])
df_csv3
# Out:
#                                   Quant Carros  \
# Região       Estado
# Sul          Acre                         4342
# Centro-Oeste Alagoas                     18991
# Sudeste      Amapá                        6463
# Centro-Oeste Amazonas                     3180
#              Bahia                       11288
# Nordeste     Ceará                       10807
# Sudeste      Distrito Federal             5786
#              Espírito Santo               5494
#              Goiás                       24412
# Centro-Oeste Maranhão                     8472
# Sul          Mato Grosso                  4868
# Sudeste      Mato Grosso do Sul           5683
# Centro-Oeste Minas Gerais                17291
# Nordeste     Pará                        22387
# Sul          Paraíba                     10666
# Nordeste     Paraná                       6036
# Sul          Pernambuco                  10533
# Centro-Oeste Piauí                        7912
# ...

# %%
df_csv3.loc[['Sul', 'Norte']]
# Out:
#                             Quant Carros  Quant Carros Família com Filhos  \
# Região Estado
# Sul    Acre                         4342                             1034
#        Mato Grosso                  4868                             3613
#        Paraíba                     10666                             2500
#        Pernambuco                  10533                             3449
#        Rio Grande do Norte          6396                             1161
#        Roraima                      3561                             1995
# Norte  Rio de Janeiro              33848                             2579
#        Santa Catarina               9466                             3317
#        São Paulo                    6317                             4934
#
#                             População do Estado  Carros por habitante  \
# Região Estado
# Sul    Acre                             23942.0              0.181355
# ...

# %%
df_csv3.loc[['Sul', 'Norte'], 'Carros por habitante']
# Out:
# Região  Estado
# Sul     Acre                   0.181355
#         Mato Grosso            0.568957
#         Paraíba                0.546918
#         Pernambuco             0.674026
#         Rio Grande do Norte    0.133192
#         Roraima                0.222340
# Norte   Rio de Janeiro         0.700453
#         Santa Catarina         0.327577
#         São Paulo              0.829874
# Name: Carros por habitante, dtype: float64

# %%
df_csv3.loc[[('Norte', 'São Paulo'), ('Sul', 'Acre')]] #indexado regiao e estado
# Out:
#                   Quant Carros  Quant Carros Família com Filhos  \
# Região Estado
# Norte  São Paulo          6317                             4934
# Sul    Acre               4342                             1034
#
#                   População do Estado  Carros por habitante  \
# Região Estado
# Norte  São Paulo               7612.0              0.829874
# Sul    Acre                   23942.0              0.181355
#
#                   Carros por habitante produtivo  Proporção
# Região Estado
# Norte  São Paulo                      829.873883   0.829874
# Sul    Acre                           181.354941   0.181355

# %%
df_csv3.sort_index() #ordena por ordem alfabetica
# Out:
#                                   Quant Carros  \
# Região       Estado
# Centro-Oeste Alagoas                     18991
#              Amazonas                     3180
#              Bahia                       11288
#              Maranhão                     8472
#              Minas Gerais                17291
#              Piauí                        7912
#              Rondônia                    23113
# Nordeste     Ceará                       10807
#              Paraná                       6036
#              Pará                        22387
#              Rio Grande do Sul            2241
# Norte        Rio de Janeiro              33848
#              Santa Catarina               9466
#              São Paulo                    6317
# Sudeste      Amapá                        6463
#              Distrito Federal             5786
#              Espírito Santo               5494
#              Goiás                       24412
# ...

# %%
df_4 = df_csv3.sort_index(level=['Região', 'Estado'], ascending=[True, False]) #ordena por ordem alfabetica
df_4
# Out:
#                                   Quant Carros  \
# Região       Estado
# Centro-Oeste Rondônia                    23113
#              Piauí                        7912
#              Minas Gerais                17291
#              Maranhão                     8472
#              Bahia                       11288
#              Amazonas                     3180
#              Alagoas                     18991
# Nordeste     Rio Grande do Sul            2241
#              Pará                        22387
#              Paraná                       6036
#              Ceará                       10807
# Norte        São Paulo                    6317
#              Santa Catarina               9466
#              Rio de Janeiro              33848
# Sudeste      Tocantins                   17144
#              Sergipe                     22307
#              Mato Grosso do Sul           5683
#              Goiás                       24412
# ...

# %%
df_4['Nordeste':'Sudeste'] #slicing de linhas
# Out:
#                              Quant Carros  Quant Carros Família com Filhos  \
# Região   Estado
# Nordeste Rio Grande do Sul           2241                             1201
#          Pará                       22387                             4893
#          Paraná                      6036                             1702
#          Ceará                      10807                             4943
# Norte    São Paulo                   6317                             4934
#          Santa Catarina              9466                             3317
#          Rio de Janeiro             33848                             2579
# Sudeste  Tocantins                  17144                             4342
#          Sergipe                    22307                             1815
#          Mato Grosso do Sul          5683                             2129
#          Goiás                      24412                             2021
# ...

# %%
df_4.loc[:,'Quant Carros':'População do Estado'] #slicing de colunas
# Out:
#                                   Quant Carros  \
# Região       Estado
# Centro-Oeste Rondônia                    23113
#              Piauí                        7912
#              Minas Gerais                17291
#              Maranhão                     8472
#              Bahia                       11288
#              Amazonas                     3180
#              Alagoas                     18991
# Nordeste     Rio Grande do Sul            2241
#              Pará                        22387
#              Paraná                       6036
#              Ceará                       10807
# Norte        São Paulo                    6317
#              Santa Catarina               9466
#              Rio de Janeiro              33848
# Sudeste      Tocantins                   17144
#              Sergipe                     22307
#              Mato Grosso do Sul           5683
#              Goiás                       24412
# ...

# %%
df_5 = df_csv3.sort_index(level=['Região', 'Estado'], ascending=[True, True]) #ambos as colunas setadas para ordem alfabetica
df_5
# Out:
#                                   Quant Carros  \
# Região       Estado
# Centro-Oeste Alagoas                     18991
#              Amazonas                     3180
#              Bahia                       11288
#              Maranhão                     8472
#              Minas Gerais                17291
#              Piauí                        7912
#              Rondônia                    23113
# Nordeste     Ceará                       10807
#              Paraná                       6036
#              Pará                        22387
#              Rio Grande do Sul            2241
# Norte        Rio de Janeiro              33848
#              Santa Catarina               9466
#              São Paulo                    6317
# Sudeste      Amapá                        6463
#              Distrito Federal             5786
#              Espírito Santo               5494
#              Goiás                       24412
# ...

# %%
df_5.loc[('Nordeste','Ceará'): ('Sudeste','Tocantins'), 'Quant Carros' : 'População do Estado'] #slicing linha e coluna
# Out:
#                              Quant Carros  Quant Carros Família com Filhos  \
# Região   Estado
# Nordeste Ceará                      10807                             4943
#          Paraná                      6036                             1702
#          Pará                       22387                             4893
#          Rio Grande do Sul           2241                             1201
# Norte    Rio de Janeiro             33848                             2579
#          Santa Catarina              9466                             3317
#          São Paulo                   6317                             4934
# Sudeste  Amapá                       6463                             4152
#          Distrito Federal            5786                             4459
#          Espírito Santo              5494                             4073
#          Goiás                      24412                             2021
# ...

# %%
df_5.iloc[0:3, :4] #busca igual de lista: o ultimo menos 1
# Out:
#                        Quant Carros  Quant Carros Família com Filhos  \
# Região       Estado
# Centro-Oeste Alagoas          18991                             3253
#              Amazonas          3180                             2955
#              Bahia            11288                             2585
#
#                        População do Estado  Carros por habitante
# Região       Estado
# Centro-Oeste Alagoas               23431.0              0.810507
#              Amazonas               5189.0              0.612835
#              Bahia                 24118.0              0.468032

# %% [markdown]
# # Valores faltosos
#
# 17. Para os valores faltosos coloque:
# - Se string: Falta informação
# - Se número: mediana
# 18. Plote a porcentagem de dados faltosos para cada coluna.

# %%
df_respostas =  pd.read_csv('dados_concurso.csv')
df_respostas
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                NaN
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88                NaN
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                NaN
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14
#
#       Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0   2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1   2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# ...

# %%
df_fillna = df_respostas.fillna('Falta informação') #17
df_fillna
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a   Falta informação
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b   Falta informação
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4   Falta informação
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88   Falta informação
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e   Falta informação
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14
#
#       Data de Inscrição                Cidade            Estado  \
# 0   2022-01-11 16:47:41  da Mota de das Neves                MS
# 1   2022-01-30 13:17:53     Teixeira do Norte                SE
# ...

# %%
df_fillna['Estado'].unique()
# Out:
# array(['MS', 'SE', 'CE', 'RN', 'PA', 'ES', 'TO', 'PR', 'AM', 'MA', 'RJ',
#        'SP', 'Falta informação', 'AP', 'PB', 'MG', 'MT', 'DF', 'BA', 'PI',
#        'RO', 'AL', 'SC', 'PE', 'GO', 'RR', 'RS'], dtype=object)

# %%
df_respostas.isna().sum().plot(kind='bar') #18
plt.show()

# %%
from matplotlib import pyplot as plt
df_graf1 = df_respostas.groupby('Estado')['Data de Inscrição'].count()
df_graf1.plot(kind='bar')
plt.show()

# %%
df_respostas.isna()
# Out:
#     Número de Inscrição  Data de Nascimento  Data de Inscrição  Cidade  \
# 0                 False                True              False   False
# 1                 False               False              False   False
# 2                 False                True              False    True
# 3                 False               False              False   False
# 4                 False               False              False   False
# ..                  ...                 ...                ...     ...
# 95                False                True              False   False
# 96                False                True              False   False
# 97                False                True              False    True
# 98                False               False              False    True
# 99                False               False              False   False
#
#     Estado   Sexo  Deficiência   Nome  Sobrenome  Escolaridade
# ...

# %%
df_respostas.isna().any() # colunas com dados NaN
# Out:
# Número de Inscrição    False
# Data de Nascimento      True
# Data de Inscrição      False
# Cidade                  True
# Estado                  True
# Sexo                    True
# Deficiência             True
# Nome                   False
# Sobrenome              False
# Escolaridade            True
# dtype: bool

# %%
df_respostas.isna().sum() #soma de dados por coluna com NaN
# Out:
# Número de Inscrição     0
# Data de Nascimento     18
# Data de Inscrição       0
# Cidade                 21
# Estado                 21
# Sexo                   16
# Deficiência            15
# Nome                    0
# Sobrenome               0
# Escolaridade           20
# dtype: int64

# %%
df_respostas.isna().sum().plot(kind='bar')
plt.show()

# %%
df_drop1 = df_respostas.dropna() #exclui linhas com NaN
df_drop
# Out:
#           Região  Quant Carros  Quant Carros Família com Filhos  \
# 0            Sul          4342                             1034
# 1   Centro-Oeste         18991                             3253
# 2        Sudeste          6463                             4152
# 3   Centro-Oeste          3180                             2955
# 4   Centro-Oeste         11288                             2585
# 5       Nordeste         10807                             4943
# 6        Sudeste          5786                             4459
# 7        Sudeste          5494                             4073
# 8        Sudeste         24412                             2021
# 9   Centro-Oeste          8472                             4461
# 10           Sul          4868                             3613
# 11       Sudeste          5683                             2129
# 12  Centro-Oeste         17291                             4843
# 13      Nordeste         22387                             4893
# ...

# %%
df_drop2 = df_respostas.dropna(axis=1) #exclui colunas com NaN
df_drop2
# Out:
#                      Número de Inscrição    Data de Inscrição           Nome  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a  2022-01-11 16:47:41    João Miguel
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a  2022-01-30 13:17:53   Maria Sophia
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b  2022-01-28 12:28:17       Giovanna
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511  2022-01-20 02:11:07    João Felipe
# 4   22369508-74a2-403b-8237-1851971a08d6  2022-01-23 21:48:36       Benjamin
# ..                                   ...                  ...            ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4  2022-01-13 17:54:11           Cauê
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88  2022-01-28 11:32:23  Maria Eduarda
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e  2022-01-14 13:27:45       Catarina
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7  2022-01-17 00:02:17       Giovanna
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8  2022-01-20 22:40:45          Eloah
#
#    Sobrenome
# 0     Castro
# 1    Rezende
# ...

# %%
df_drop3 = df_respostas.dropna(subset=['Estado']) #exclui linhas com NaN na coluna Estado
df_drop3
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 93  67bc6c78-b15e-400d-a4c0-f998210fb3f9         1910-05-22
# 94  72fdbd78-b0fe-4b80-bb34-201c285e66c6         1946-10-04
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                NaN
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                NaN
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
#
#       Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0   2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1   2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# ...

# %%
df_sub = df_respostas.fillna(0) #substitui NaN por 0
df_sub
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                  0
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                  0
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                  0
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88                  0
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                  0
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14
#
#       Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0   2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1   2022-01-30 13:17:53     Teixeira do Norte     SE    0         Não
# ...

# %%
df_sub1 = df_respostas.fillna(df_respostas.median(numeric_only=True)) #substitui NaN pela mediana
df_sub1
# Out:
#                      Número de Inscrição Data de Nascimento  \
# 0   f2bf14e6-9ecc-43d1-9098-1a133277d26a                NaN
# 1   afd1d890-dbfd-4d72-a9a2-4309f356167a         1910-02-05
# 2   16451a82-28f8-48bf-a5b6-9f0c5b25ef6b                NaN
# 3   200731b4-a651-4a2d-9d01-11d4d6a41511         1949-11-21
# 4   22369508-74a2-403b-8237-1851971a08d6         1963-06-26
# ..                                   ...                ...
# 95  b162a88d-6afa-46aa-afbe-f5b0e0d13ce4                NaN
# 96  25e9b106-2c3d-444d-b7d4-ae34ad33bc88                NaN
# 97  4ffbc174-78af-4da1-a53a-b442c20a876e                NaN
# 98  d4e8e12a-3298-4ff1-a80f-2946431bd5a7         1916-06-21
# 99  7af3e5da-99a2-4f0f-900c-cbc194351ce8         1959-03-14
#
#       Data de Inscrição                Cidade Estado Sexo Deficiência  \
# 0   2022-01-11 16:47:41  da Mota de das Neves     MS    F         Sim
# 1   2022-01-30 13:17:53     Teixeira do Norte     SE  NaN         Não
# ...
